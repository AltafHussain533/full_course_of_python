# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data import
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=df.fillna(value=df[['age']].mean())

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.info()         # object means categorial variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age             0.000000
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df.drop(columns='deck')
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df.drop(columns='deck',inplace=True)

# %%
df=df.fillna(value=df[['age']].mean())

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df['age']=df.age.fillna(value=df[['age']].mean())

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df['embarked']=df.embarked.fillna(value=df['embarked'].mode())

# %%
df['embark_town']=df.embark_town.fillna(value=df['embark_town'].mode())

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df['embarked']=df.embarked.fillna(value=df['embarked'].mode()[0])     #  [0] is means take replace one mode

# %%
df['embark_town']=df.embark_town.fillna(value=df['embark_town'].mode()[0])

# %%
df.isnull().sum()/len(df)*100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %%
df.to_excel('df.xlsx')

# %% [markdown]
# # Outlier removal

# %% [markdown]
# # Visualization wala method:

# %%
sns.boxplot(data=df,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=df,y='age',x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=df,y='age')
# Out:
# <Axes: ylabel='age'>

# %%
# IQR method
Q1=df['age'].quantile(0.25)
Q3=df['age'].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# np.float64(13.0)

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df=df[(df['age']>lower_bound)&(df['age']<upper_bound)]

# %%
df.shape
# Out:
# (825, 14)

# %%
# IQR method
Q1=df['age'].quantile(0.25)
Q3=df['age'].quantile(0.75)
IQR=Q3-Q1
IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df=df[(df['age']>lower_bound)&(df['age']<upper_bound)]

# %%
sns.boxplot(data=df,y='age')
# Out:
# <Axes: ylabel='age'>

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
# IQR method
Q1=df['fare'].quantile(0.25)
Q3=df['fare'].quantile(0.75)
IQR=Q3-Q1
IQR
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
df=df[(df['fare']>lower_bound)&(df['fare']<upper_bound)]

# %%
sns.histplot(df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.boxplot(data=df,y='fare')
# Out:
# <Axes: ylabel='fare'>

# %%
df.shape
# Out:
# (693, 14)

# %%
# Z Score method
from scipy import stats
import numpy as np
import pandas as pd
zscore=np.abs(stats.zscore(df['age']))
threshold=3
df=df[(z<threshold).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[103], line 7
#       5 zscore=np.abs(stats.zscore(df['age']))
#       6 threshold=3
# ----> 7 df=df[(z<threshold).all(axis=1)]
#
# NameError: name 'z' is not defined

# %%
from scipy import stats
import numpy as np
import pandas as pd # Import pandas if not already done

# Assuming 'df' is your existing pandas DataFrame
# Example DataFrame for testing (replace with your actual data)
# data = {'age': [20, 22, 25, 24, 26, 28, 30, 80, 23, 25, 27, 29, 31, 100]}
# df = pd.DataFrame(data)

# Calculate the absolute Z-scores for the 'age' column
zscore = np.abs(stats.zscore(df['age']))

# Define the threshold (commonly 3)
threshold = 3

# Create a boolean mask indicating which rows are NOT outliers
# The condition `zscore < threshold` evaluates to True for non-outliers
non_outlier_mask = zscore < threshold

# Filter the DataFrame using the boolean mask
df_filtered = df[non_outlier_mask]

# Optional: View the shape of the original vs filtered data
# print(f"Original shape: {df.shape}")
# print(f"Filtered shape: {df_filtered.shape}")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 14)

# %% [markdown]
# # find and dropping duplicates

# %%
# findig duplicates
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# findig duplicates
df.drop_duplicates()
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (784, 15)

# %%
len(df)      # lenght of dataframe
# Out:
# 780

# %% [markdown]
# # box plot
# For boxplot one variable is numeric and other varible is categorical
# # histogram
# In hisplot both variable are numerical
# in boxplot take categorical variable on x-axis and numerical on y-axis
# # Scatterplot
# If both varibles are numerical on x-axis and y-axis then use scatter plot

# %% [markdown]
# # Assignment
# Why Boston data delect from sicikit learn (see from net (chatgpt or google))

# %%
df.shape
# Out:
# (693, 14)

# %%
# finding and dropping duplicates 
# find duplicates
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
# df1=df.duplicated()

# %%
# df1.shape
# Out:
# (891,)

# %%
# dropping 
df.drop_duplicates(inplace=True)

# %%
# df1.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_duplicates=df[df.duplicated()]
df_duplicates.head(55)
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 47          1       3  female  29.699118      0      0   7.7500        Q
# 76          0       3    male  29.699118      0      0   7.8958        S
# 77          0       3    male  29.699118      0      0   8.0500        S
# 87          0       3    male  29.699118      0      0   8.0500        S
# 95          0       3    male  29.699118      0      0   8.0500        S
# 101         0       3    male  29.699118      0      0   7.8958        S
# 121         0       3    male  29.699118      0      0   8.0500        S
# 133         1       2  female  29.000000      1      0  26.0000        S
# 173         0       3    male  21.000000      0      0   7.9250        S
# 196         0       3    male  29.699118      0      0   7.7500        Q
# 198         1       3  female  29.699118      0      0   7.7500        Q
# 213         0       2    male  30.000000      0      0  13.0000        S
# ...

# %%
df_duplicates_count.plot(kind='bar')
plt.title('Frequency of Duplicate Rows')
plt.xlabel('Duplicate Row Combination')
plt.ylabel('Count')
plt.show()

# %%
df_duplicates=df[df.duplicated()]
df_duplicates_count=df_duplicates.value_counts()

plt.bar(df_duplicates_count.index,df_duplicates_count.values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:2624, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2623 try:
# -> 2624     left = x - width / 2
#    2625 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'tuple' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[325], line 4
#       1 df_duplicates=df[df.duplicated()]
#       2 df_duplicates_count=df_duplicates.value_counts()
# ----> 4 plt.bar(df_duplicates_count.index,df_duplicates_count.values)
#       5 plt.show()
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\matplotlib\pyplot.py:2990, in bar(x, height, width, bottom, align, data, **kwargs)
# ...

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
plt.bar(df_duplicates_count.index,df_duplicates_count.values)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Example data simulation
# data = {'col1': ['A', 'B', 'A', 'C', 'B', 'A', 'D', 'C']}
# df = pd.DataFrame(data)
# df_duplicates_count = df['col1'].value_counts()
# print(df_duplicates_count)
# Out:
# col1
# A    3
# B    2
# C    2
# D    1
# Name: count, dtype: int64

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# plt.bar(df_duplicates_count.index, df_duplicates_count.values)
# plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Data Normalization

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# 2 data
df
# 3 select column to normize
cols_to_normaliz=['age','fare']
# 4 Create the scaler functon/tool
scaler=MinMaxScaler()
# 5 fit and transorm the data scaler or vice versa
df[cols_to_normaliz]=scaler.fit_transform(df[cols_to_normaliz])
# 6 check the data
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.369565      1      0  0.118118        S
# 2           1       3  female  0.456522      0      0  0.129115        S
# 3           1       1  female  0.652174      1      0  0.865114        S
# 4           0       3    male  0.652174      0      0  0.131152        S
# 5           0       3    male  0.536937      0      0  0.137804        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male  0.478261      0      0  0.211798        S
# 887         1       1  female  0.304348      0      0  0.488765        S
# 888         0       3  female  0.536937      1      2  0.382051        S
# 889         1       1    male  0.456522      0      0  0.488765        C
# 890         0       3    male  0.586957      0      0  0.126264        Q
#
#       class    who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# # x_standard=(x-mean(x))/std(x)
# # where:
#
#  x_standar is the standardize variable
#
#  x is the original variable
#
#  mean(x) is the mean of the variable x
#
#  std(x) is the standard deviation of x

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  693.000000  693.000000  693.000000  693.000000  693.000000  693.000000
# mean     0.324675    2.522367    0.513968    0.382395    0.295815    0.274303
# std      0.468592    0.714126    0.196816    0.816790    0.773811    0.213816
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.391304    0.000000    0.000000    0.127962
# 50%      0.000000    3.000000    0.536937    0.000000    0.000000    0.171068
# 75%      1.000000    3.000000    0.586957    1.000000    0.000000    0.393456
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %% [markdown]
# # Log transformation

# %%
kashti=sns.load_dataset('titanic')
kashti.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import numpy as np

# %%
kashti['age']=kashti['age'].fillna(kashti['age'].median())
kashti['fare']=kashti['fare'].fillna(kashti['fare'].median())

# %%
kashti
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  1.128508      1      0  0.683603        S
# 1           1       1  female  1.291320      1      0  1.450832        C
# 2           1       3  female  1.181143      0      0  0.727559        S
# 3           1       1  female  1.268453      1      0  1.379314        S
# 4           0       3    male  1.268453      0      0  0.735091        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male  1.192660      0      0  0.941939        S
# 887         1       1  female  1.079918      0      0  1.224128        S
# 888         0       3  female  1.203634      1      2  1.148947        S
# 889         1       1    male  1.181143      0      0  1.224128        C
# 890         0       3    male  1.242925      0      0  0.716714        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti['age']=kashti['age'].fillna(kashti['age'].median())
kashti['fare']=kashti['fare'].fillna(kashti['fare'].median())

# log transform
kashti['age']=np.log(kashti['age'])
kashti['fare']=np.log(kashti['fare'])
kashti.head()
# Out:
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  1.128508      1      0  0.683603        S  Third
# 1         1       1  female  1.291320      1      0  1.450832        C  First
# 2         1       3  female  1.181143      0      0  0.727559        S  Third
# 3         1       1  female  1.268453      1      0  1.379314        S  First
# 4         0       3    male  1.268453      0      0  0.735091        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
kashti
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  1.128508      1      0  0.683603        S
# 1           1       1  female  1.291320      1      0  1.450832        C
# 2           1       3  female  1.181143      0      0  0.727559        S
# 3           1       1  female  1.268453      1      0  1.379314        S
# 4           0       3    male  1.268453      0      0  0.735091        S
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 886         0       2    male  1.192660      0      0  0.941939        S
# 887         1       1  female  1.079918      0      0  1.224128        S
# 888         0       3  female  1.203634      1      2  1.148947        S
# 889         1       1    male  1.181143      0      0  1.224128        C
# 890         0       3    male  1.242925      0      0  0.716714        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
sns.barplot(data=kashti,x='sex',y='age')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=kashti,x="sex",y="age")
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data=kashti,x="sex",y="fare")         # without log boxplot
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxplot(data=kashti,x="sex",y="fare")       # after apply log boxpot of fare
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.histplot(kashti['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# # Origanizing the data

# %%
df['family_size']=df['sibsp']+df['parch']

# %%
sns.histplot(df['family_size'])
# Out:
# <Axes: xlabel='family_size', ylabel='Count'>

# %%
sns.swarmplot(data=df,x='sex',y='family_size')
# Out:
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 69.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 26.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='family_size'>
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 78.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 48.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.swarmplot(data=df,x='sex',y="age", hue='family_size')
# Out:
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 17.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='sex', ylabel='age'>
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 12.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
df=df.rename(columns={'survived':"survival"})
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family_size'],
#       dtype='object')

# %%
table=pd.pivot_table(df,values='fare',index='pclass',columns="survival",aggfunc=np.sum)
table
# Out:
# C:\Users\Hair\AppData\Local\Temp\ipykernel_5804\1378367512.py:1: FutureWarning: The provided callable <function sum at 0x00000243FC0DB740> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values='fare',index='pclass',columns="survival",aggfunc=np.sum)
# survival          0          1
# pclass
# 1         1330.5290  2009.1503
# 2         1326.6458  1400.7625
# 3         4197.8535  1402.7708

# %%
table=pd.pivot_table(df,values='fare',index='pclass',columns="survival",aggfunc=np.mean)
table
# Out:
# C:\Users\Hair\AppData\Local\Temp\ipykernel_5804\931067810.py:1: FutureWarning: The provided callable <function mean at 0x00000243FC108B80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table=pd.pivot_table(df,values='fare',index='pclass',columns="survival",aggfunc=np.mean)
# survival          0          1
# pclass
# 1         33.263225  40.183006
# 2         16.378343  20.010893
# 3         12.097561  13.359722

# %%
table=pd.pivot_table(df,values='age',index='pclass',columns="survival",aggfunc=np.sum)
table
# Out:
# C:\Users\Hair\AppData\Local\Temp\ipykernel_5804\3293615170.py:1: FutureWarning: The provided callable <function sum at 0x00000243FC0DB740> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values='age',index='pclass',columns="survival",aggfunc=np.sum)
# survival            0            1
# pclass
# 1         1446.287647  1676.592941
# 2         2475.893824  2000.296471
# 3         9577.416176  2672.770000

# %%
table=pd.pivot_table(df,values='fare',index='sex',columns="survival",aggfunc=np.sum)
table
# Out:
# C:\Users\Hair\AppData\Local\Temp\ipykernel_5804\774125519.py:1: FutureWarning: The provided callable <function sum at 0x00000243FC0DB740> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values='fare',index='sex',columns="survival",aggfunc=np.sum)
# survival          0          1
# sex
# female    1252.0127  3074.9586
# male      5603.0156  1737.7250

# %%
table=pd.pivot_table(df,values='fare',index='who',columns="survival",aggfunc=np.sum)
table
# Out:
# C:\Users\Hair\AppData\Local\Temp\ipykernel_5804\3786031593.py:1: FutureWarning: The provided callable <function sum at 0x00000243FC0DB740> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values='fare',index='who',columns="survival",aggfunc=np.sum)
# survival          0          1
# who
# child      602.5084   371.0126
# man       5239.3864  1640.8333
# woman     1013.1335  2800.8377

# %%
sns.scatterplot(data=df,x='fare',y='age')
df.head()
# Out:
#    survival  pclass     sex        age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.000000      1      0   7.2500        S  Third
# 2         1       3  female  26.000000      0      0   7.9250        S  Third
# 3         1       1  female  35.000000      1      0  53.1000        S  First
# 4         0       3    male  35.000000      0      0   8.0500        S  Third
# 5         0       3    male  29.699118      0      0   8.4583        Q  Third
#
#      who  adult_male  embark_town alive  alone  family_size
# 0    man        True  Southampton    no  False            1
# 2  woman       False  Southampton   yes   True            0
# 3  woman       False  Southampton   yes  False            1
# 4    man        True  Southampton    no   True            0
# 5    man        True   Queenstown    no   True            0

# %% [markdown]
# # Saving the wrangled data

# %%
df.to_csv("preprocessed_data.csv")

# %%
sns.lineplot(data=df,x="family_size",y="age")
# Out:
# <Axes: xlabel='family_size', ylabel='age'>

# %%
sns.lineplot(data=df,x="fare",y="age")
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.lineplot(data=df,x="sex",y="age")
# Out:
# <Axes: xlabel='sex', ylabel='age'>
