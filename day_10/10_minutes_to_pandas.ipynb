# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates=pd.date_range("2013",periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates=pd.date_range("2013",periods=30)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(30, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.588593  0.317592  0.729468  0.972134
# 2013-01-02 -0.597547 -1.566374 -0.023017  0.336607
# 2013-01-03  0.006409 -1.175523 -0.855528  0.556794
# 2013-01-04 -0.084007 -0.702334  1.032373 -1.848166
# 2013-01-05  1.789417  0.153277  0.147893 -0.584941
# 2013-01-06  0.557691 -1.256196 -0.189622  1.331474
# 2013-01-07 -0.577706 -0.103495 -0.589781  0.094531
# 2013-01-08  1.993748 -0.414805 -1.125184 -1.280418
# 2013-01-09  0.199293  1.665368  0.550820 -0.968745
# 2013-01-10 -0.983490 -1.621226  0.351434  0.211844
# 2013-01-11 -0.311541  0.010199 -1.225847 -0.568905
# 2013-01-12 -0.838615 -0.389461 -0.513284  0.660804
# 2013-01-13  0.134320 -0.589075  0.176931  0.252838
# 2013-01-14  0.477458  0.269147  2.583363 -2.079179
# 2013-01-15  0.956574  0.176675  1.259434 -0.477884
# 2013-01-16 -0.305994 -0.430315  0.041421  0.340111
# 2013-01-17  0.126396 -1.122639 -1.024674 -0.048960
# 2013-01-18 -1.052504  0.109429 -1.791414  0.234449
# 2013-01-19 -0.247480  0.455917 -0.741922  0.149275
# 2013-01-20  0.564542 -0.249799 -0.794213 -0.132376
# 2013-01-21 -0.374967 -2.144855  0.762714 -3.041238
# 2013-01-22  0.180451  0.725769 -2.041857  0.428397
# 2013-01-23  2.090482  0.352674  1.384797  0.104162
# 2013-01-24  0.472641 -0.271681  0.842650 -0.969039
# 2013-01-25  0.199582  2.353817 -0.685744  0.288556
# 2013-01-26 -0.000003 -0.752249 -1.781774 -1.385982
# 2013-01-27  0.728448 -0.168666 -0.407846 -0.535691
# 2013-01-28  0.498953 -0.066302 -0.600534  0.611365
# 2013-01-29  0.902028 -0.185382 -0.528436 -1.092571
# 2013-01-30 -1.091206 -1.508589  0.099588  0.409997

# %%
df2 = pd.DataFrame(
     {
                 "A": 1.0,
                 "B": pd.Timestamp("20130102"),
                "C": pd.Series(1, index=list(range(4)), dtype="float32"),
                "D": np.array([3] * 4, dtype="int32"),
                "E": pd.Categorical(["test", "train", "test", "train"]),
                "F": "foo",
        }
    ) 
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.tail()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[-5.88593496e-01,  3.17591657e-01,  7.29468411e-01,
#          9.72133719e-01],
#        [-5.97547002e-01, -1.56637373e+00, -2.30165674e-02,
#          3.36607296e-01],
#        [ 6.40923787e-03, -1.17552305e+00, -8.55528224e-01,
#          5.56794389e-01],
#        [-8.40072750e-02, -7.02334156e-01,  1.03237253e+00,
#         -1.84816627e+00],
#        [ 1.78941687e+00,  1.53277473e-01,  1.47892831e-01,
#         -5.84941155e-01],
#        [ 5.57690884e-01, -1.25619635e+00, -1.89621821e-01,
#          1.33147406e+00],
#        [-5.77706043e-01, -1.03495262e-01, -5.89781034e-01,
#          9.45310241e-02],
#        [ 1.99374752e+00, -4.14804566e-01, -1.12518393e+00,
#         -1.28041763e+00],
#        [ 1.99293267e-01,  1.66536790e+00,  5.50820472e-01,
#         -9.68745126e-01],
#        [-9.83490196e-01, -1.62122555e+00,  3.51434019e-01,
#          2.11844131e-01],
#        [-3.11540543e-01,  1.01986966e-02, -1.22584667e+00,
#         -5.68904627e-01],
#        [-8.38614637e-01, -3.89461072e-01, -5.13283988e-01,
#          6.60803688e-01],
#        [ 1.34319507e-01, -5.89075138e-01,  1.76931481e-01,
#          2.52838239e-01],
#        [ 4.77458128e-01,  2.69147365e-01,  2.58336270e+00,
#         -2.07917942e+00],
#        [ 9.56574492e-01,  1.76675422e-01,  1.25943365e+00,
#         -4.77883589e-01],
#        [-3.05993554e-01, -4.30314807e-01,  4.14208711e-02,
#          3.40110869e-01],
#        [ 1.26396451e-01, -1.12263914e+00, -1.02467358e+00,
#         -4.89602353e-02],
#        [-1.05250417e+00,  1.09429164e-01, -1.79141368e+00,
#          2.34449020e-01],
#        [-2.47480279e-01,  4.55916644e-01, -7.41921738e-01,
#          1.49274535e-01],
#        [ 5.64541984e-01, -2.49799421e-01, -7.94212606e-01,
#         -1.32375823e-01],
#        [-3.74966882e-01, -2.14485491e+00,  7.62714142e-01,
#         -3.04123751e+00],
#        [ 1.80451276e-01,  7.25768508e-01, -2.04185662e+00,
#          4.28397298e-01],
#        [ 2.09048221e+00,  3.52673989e-01,  1.38479732e+00,
#          1.04161823e-01],
#        [ 4.72641347e-01, -2.71680974e-01,  8.42649501e-01,
#         -9.69038698e-01],
#        [ 1.99581839e-01,  2.35381686e+00, -6.85743693e-01,
#          2.88556257e-01],
#        [-3.00905300e-06, -7.52248701e-01, -1.78177418e+00,
#         -1.38598216e+00],
#        [ 7.28447647e-01, -1.68666186e-01, -4.07846489e-01,
#         -5.35690579e-01],
#        [ 4.98952590e-01, -6.63017575e-02, -6.00534074e-01,
#          6.11364744e-01],
#        [ 9.02027584e-01, -1.85382434e-01, -5.28436046e-01,
#         -1.09257076e+00],
#        [-1.09120581e+00, -1.50858875e+00,  9.95884723e-02,
#          4.09997447e-01]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -0.588593   -0.597547    0.006409   -0.084007    1.789417    0.557691
# B    0.317592   -1.566374   -1.175523   -0.702334    0.153277   -1.256196
# C    0.729468   -0.023017   -0.855528    1.032373    0.147893   -0.189622
# D    0.972134    0.336607    0.556794   -1.848166   -0.584941    1.331474
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2013-01-21  \
# A   -0.577706    1.993748    0.199293   -0.983490  ...   -0.374967
# B   -0.103495   -0.414805    1.665368   -1.621226  ...   -2.144855
# C   -0.589781   -1.125184    0.550820    0.351434  ...    0.762714
# D    0.094531   -1.280418   -0.968745    0.211844  ...   -3.041238
#
#    2013-01-22  2013-01-23  2013-01-24  2013-01-25  2013-01-26  2013-01-27  \
# A    0.180451    2.090482    0.472641    0.199582   -0.000003    0.728448
# B    0.725769    0.352674   -0.271681    2.353817   -0.752249   -0.168666
# C   -2.041857    1.384797    0.842650   -0.685744   -1.781774   -0.407846
# D    0.428397    0.104162   -0.969039    0.288556   -1.385982   -0.535691
#
#    2013-01-28  2013-01-29  2013-01-30
# A    0.498953    0.902028   -1.091206
# B   -0.066302   -0.185382   -1.508589
# C   -0.600534   -0.528436    0.099588
# D    0.611365   -1.092571    0.409997
#
# [4 rows x 30 columns]

# %%
df.describe()
# Out:
#                A          B          C          D
# count  30.000000  30.000000  30.000000  30.000000
# mean    0.160826  -0.270970  -0.165260  -0.267692
# std     0.828638   0.938042   1.033055   0.971646
# min    -1.091206  -2.144855  -2.041857  -3.041238
# 25%    -0.359110  -0.739770  -0.781140  -0.872794
# 50%     0.130358  -0.217591  -0.298734   0.099346
# 75%     0.543006   0.170826   0.500974   0.339235
# max     2.090482   2.353817   2.583363   1.331474

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  0.972134  0.729468  0.317592 -0.588593
# 2013-01-02  0.336607 -0.023017 -1.566374 -0.597547
# 2013-01-03  0.556794 -0.855528 -1.175523  0.006409
# 2013-01-04 -1.848166  1.032373 -0.702334 -0.084007
# 2013-01-05 -0.584941  0.147893  0.153277  1.789417
# 2013-01-06  1.331474 -0.189622 -1.256196  0.557691
# 2013-01-07  0.094531 -0.589781 -0.103495 -0.577706
# 2013-01-08 -1.280418 -1.125184 -0.414805  1.993748
# 2013-01-09 -0.968745  0.550820  1.665368  0.199293
# 2013-01-10  0.211844  0.351434 -1.621226 -0.983490
# 2013-01-11 -0.568905 -1.225847  0.010199 -0.311541
# 2013-01-12  0.660804 -0.513284 -0.389461 -0.838615
# 2013-01-13  0.252838  0.176931 -0.589075  0.134320
# 2013-01-14 -2.079179  2.583363  0.269147  0.477458
# 2013-01-15 -0.477884  1.259434  0.176675  0.956574
# 2013-01-16  0.340111  0.041421 -0.430315 -0.305994
# 2013-01-17 -0.048960 -1.024674 -1.122639  0.126396
# 2013-01-18  0.234449 -1.791414  0.109429 -1.052504
# 2013-01-19  0.149275 -0.741922  0.455917 -0.247480
# 2013-01-20 -0.132376 -0.794213 -0.249799  0.564542
# 2013-01-21 -3.041238  0.762714 -2.144855 -0.374967
# 2013-01-22  0.428397 -2.041857  0.725769  0.180451
# 2013-01-23  0.104162  1.384797  0.352674  2.090482
# 2013-01-24 -0.969039  0.842650 -0.271681  0.472641
# 2013-01-25  0.288556 -0.685744  2.353817  0.199582
# 2013-01-26 -1.385982 -1.781774 -0.752249 -0.000003
# 2013-01-27 -0.535691 -0.407846 -0.168666  0.728448
# 2013-01-28  0.611365 -0.600534 -0.066302  0.498953
# 2013-01-29 -1.092571 -0.528436 -0.185382  0.902028
# 2013-01-30  0.409997  0.099588 -1.508589 -1.091206

# %%
df.sort_values(by="B")      # sort by values
# Out:
#                    A         B         C         D
# 2013-01-21 -0.374967 -2.144855  0.762714 -3.041238
# 2013-01-10 -0.983490 -1.621226  0.351434  0.211844
# 2013-01-02 -0.597547 -1.566374 -0.023017  0.336607
# 2013-01-30 -1.091206 -1.508589  0.099588  0.409997
# 2013-01-06  0.557691 -1.256196 -0.189622  1.331474
# 2013-01-03  0.006409 -1.175523 -0.855528  0.556794
# 2013-01-17  0.126396 -1.122639 -1.024674 -0.048960
# 2013-01-26 -0.000003 -0.752249 -1.781774 -1.385982
# 2013-01-04 -0.084007 -0.702334  1.032373 -1.848166
# 2013-01-13  0.134320 -0.589075  0.176931  0.252838
# 2013-01-16 -0.305994 -0.430315  0.041421  0.340111
# 2013-01-08  1.993748 -0.414805 -1.125184 -1.280418
# 2013-01-12 -0.838615 -0.389461 -0.513284  0.660804
# 2013-01-24  0.472641 -0.271681  0.842650 -0.969039
# 2013-01-20  0.564542 -0.249799 -0.794213 -0.132376
# 2013-01-29  0.902028 -0.185382 -0.528436 -1.092571
# 2013-01-27  0.728448 -0.168666 -0.407846 -0.535691
# 2013-01-07 -0.577706 -0.103495 -0.589781  0.094531
# 2013-01-28  0.498953 -0.066302 -0.600534  0.611365
# 2013-01-11 -0.311541  0.010199 -1.225847 -0.568905
# 2013-01-18 -1.052504  0.109429 -1.791414  0.234449
# 2013-01-05  1.789417  0.153277  0.147893 -0.584941
# 2013-01-15  0.956574  0.176675  1.259434 -0.477884
# 2013-01-14  0.477458  0.269147  2.583363 -2.079179
# 2013-01-01 -0.588593  0.317592  0.729468  0.972134
# 2013-01-23  2.090482  0.352674  1.384797  0.104162
# 2013-01-19 -0.247480  0.455917 -0.741922  0.149275
# 2013-01-22  0.180451  0.725769 -2.041857  0.428397
# 2013-01-09  0.199293  1.665368  0.550820 -0.968745
# 2013-01-25  0.199582  2.353817 -0.685744  0.288556

# %%
df["A"]
# Out:
# 2013-01-01   -0.588593
# 2013-01-02   -0.597547
# 2013-01-03    0.006409
# 2013-01-04   -0.084007
# 2013-01-05    1.789417
# 2013-01-06    0.557691
# 2013-01-07   -0.577706
# 2013-01-08    1.993748
# 2013-01-09    0.199293
# 2013-01-10   -0.983490
# 2013-01-11   -0.311541
# 2013-01-12   -0.838615
# 2013-01-13    0.134320
# 2013-01-14    0.477458
# 2013-01-15    0.956574
# 2013-01-16   -0.305994
# 2013-01-17    0.126396
# 2013-01-18   -1.052504
# 2013-01-19   -0.247480
# 2013-01-20    0.564542
# 2013-01-21   -0.374967
# 2013-01-22    0.180451
# 2013-01-23    2.090482
# 2013-01-24    0.472641
# 2013-01-25    0.199582
# 2013-01-26   -0.000003
# 2013-01-27    0.728448
# 2013-01-28    0.498953
# 2013-01-29    0.902028
# 2013-01-30   -1.091206
# Freq: D, Name: A, dtype: float64

# %%
# For a DataFrame, passing a slice : selects matching rows:
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.588593  0.317592  0.729468  0.972134
# 2013-01-02 -0.597547 -1.566374 -0.023017  0.336607
# 2013-01-03  0.006409 -1.175523 -0.855528  0.556794

# %%
df.loc[dates[0]]
# Out:
# A   -0.588593
# B    0.317592
# C    0.729468
# D    0.972134
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
# Selecting all rows (:) with a select column labels:
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.588593  0.317592
# 2013-01-02 -0.597547 -1.566374
# 2013-01-03  0.006409 -1.175523
# 2013-01-04 -0.084007 -0.702334
# 2013-01-05  1.789417  0.153277
# 2013-01-06  0.557691 -1.256196
# 2013-01-07 -0.577706 -0.103495
# 2013-01-08  1.993748 -0.414805
# 2013-01-09  0.199293  1.665368
# 2013-01-10 -0.983490 -1.621226
# 2013-01-11 -0.311541  0.010199
# 2013-01-12 -0.838615 -0.389461
# 2013-01-13  0.134320 -0.589075
# 2013-01-14  0.477458  0.269147
# 2013-01-15  0.956574  0.176675
# 2013-01-16 -0.305994 -0.430315
# 2013-01-17  0.126396 -1.122639
# 2013-01-18 -1.052504  0.109429
# 2013-01-19 -0.247480  0.455917
# 2013-01-20  0.564542 -0.249799
# 2013-01-21 -0.374967 -2.144855
# 2013-01-22  0.180451  0.725769
# 2013-01-23  2.090482  0.352674
# 2013-01-24  0.472641 -0.271681
# 2013-01-25  0.199582  2.353817
# 2013-01-26 -0.000003 -0.752249
# 2013-01-27  0.728448 -0.168666
# 2013-01-28  0.498953 -0.066302
# 2013-01-29  0.902028 -0.185382
# 2013-01-30 -1.091206 -1.508589

# %%
# For label slicing, both endpoints are included:
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -0.597547 -1.566374
# 2013-01-03  0.006409 -1.175523
# 2013-01-04 -0.084007 -0.702334

# %%
# Selecting a single row and column label returns a scalar:
df.loc[dates[0], "A"]
# Out:
# np.float64(-0.5885934958156026)

# %%
# For getting fast access to a scalar (equivalent to the prior method):
df.at[dates[0], "A"]
# Out:
# np.float64(-0.5885934958156026)

# %%
# Selection by Position using DataFrame.iloc() or DataFrame.iat()
df.iloc[3]
# Out:
# A   -0.084007
# B   -0.702334
# C    1.032373
# D   -1.848166
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.084007 -0.702334
# 2013-01-05  1.789417  0.153277

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.597547 -0.023017
# 2013-01-03  0.006409 -0.855528
# 2013-01-05  1.789417  0.147893

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.597547 -1.566374 -0.023017  0.336607
# 2013-01-03  0.006409 -1.175523 -0.855528  0.556794

# %%
# For slicing columns explicitly:
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.317592  0.729468
# 2013-01-02 -1.566374 -0.023017
# 2013-01-03 -1.175523 -0.855528
# 2013-01-04 -0.702334  1.032373
# 2013-01-05  0.153277  0.147893
# 2013-01-06 -1.256196 -0.189622
# 2013-01-07 -0.103495 -0.589781
# 2013-01-08 -0.414805 -1.125184
# 2013-01-09  1.665368  0.550820
# 2013-01-10 -1.621226  0.351434
# 2013-01-11  0.010199 -1.225847
# 2013-01-12 -0.389461 -0.513284
# 2013-01-13 -0.589075  0.176931
# 2013-01-14  0.269147  2.583363
# 2013-01-15  0.176675  1.259434
# 2013-01-16 -0.430315  0.041421
# 2013-01-17 -1.122639 -1.024674
# 2013-01-18  0.109429 -1.791414
# 2013-01-19  0.455917 -0.741922
# 2013-01-20 -0.249799 -0.794213
# 2013-01-21 -2.144855  0.762714
# 2013-01-22  0.725769 -2.041857
# 2013-01-23  0.352674  1.384797
# 2013-01-24 -0.271681  0.842650
# 2013-01-25  2.353817 -0.685744
# 2013-01-26 -0.752249 -1.781774
# 2013-01-27 -0.168666 -0.407846
# 2013-01-28 -0.066302 -0.600534
# 2013-01-29 -0.185382 -0.528436
# 2013-01-30 -1.508589  0.099588

# %%
# For slicing columns explicitly:
df.iloc[:, 0:3]
# Out:
#                    A         B         C
# 2013-01-01 -0.588593  0.317592  0.729468
# 2013-01-02 -0.597547 -1.566374 -0.023017
# 2013-01-03  0.006409 -1.175523 -0.855528
# 2013-01-04 -0.084007 -0.702334  1.032373
# 2013-01-05  1.789417  0.153277  0.147893
# 2013-01-06  0.557691 -1.256196 -0.189622
# 2013-01-07 -0.577706 -0.103495 -0.589781
# 2013-01-08  1.993748 -0.414805 -1.125184
# 2013-01-09  0.199293  1.665368  0.550820
# 2013-01-10 -0.983490 -1.621226  0.351434
# 2013-01-11 -0.311541  0.010199 -1.225847
# 2013-01-12 -0.838615 -0.389461 -0.513284
# 2013-01-13  0.134320 -0.589075  0.176931
# 2013-01-14  0.477458  0.269147  2.583363
# 2013-01-15  0.956574  0.176675  1.259434
# 2013-01-16 -0.305994 -0.430315  0.041421
# 2013-01-17  0.126396 -1.122639 -1.024674
# 2013-01-18 -1.052504  0.109429 -1.791414
# 2013-01-19 -0.247480  0.455917 -0.741922
# 2013-01-20  0.564542 -0.249799 -0.794213
# 2013-01-21 -0.374967 -2.144855  0.762714
# 2013-01-22  0.180451  0.725769 -2.041857
# 2013-01-23  2.090482  0.352674  1.384797
# 2013-01-24  0.472641 -0.271681  0.842650
# 2013-01-25  0.199582  2.353817 -0.685744
# 2013-01-26 -0.000003 -0.752249 -1.781774
# 2013-01-27  0.728448 -0.168666 -0.407846
# 2013-01-28  0.498953 -0.066302 -0.600534
# 2013-01-29  0.902028 -0.185382 -0.528436
# 2013-01-30 -1.091206 -1.508589  0.099588

# %%
# For getting a value explicitly:
df.iloc[1, 1]
# Out:
# np.float64(-1.5663737285555277)

# %%
# For getting fast access to a scalar (equivalent to the prior method):
df.iat[1, 1]
# Out:
# np.float64(-1.5663737285555277)

# %%
# Boolean indexing
# Select rows where df.A is greater than 0.
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-03  0.006409 -1.175523 -0.855528  0.556794
# 2013-01-05  1.789417  0.153277  0.147893 -0.584941
# 2013-01-06  0.557691 -1.256196 -0.189622  1.331474
# 2013-01-08  1.993748 -0.414805 -1.125184 -1.280418
# 2013-01-09  0.199293  1.665368  0.550820 -0.968745
# 2013-01-13  0.134320 -0.589075  0.176931  0.252838
# 2013-01-14  0.477458  0.269147  2.583363 -2.079179
# 2013-01-15  0.956574  0.176675  1.259434 -0.477884
# 2013-01-17  0.126396 -1.122639 -1.024674 -0.048960
# 2013-01-20  0.564542 -0.249799 -0.794213 -0.132376
# 2013-01-22  0.180451  0.725769 -2.041857  0.428397
# 2013-01-23  2.090482  0.352674  1.384797  0.104162
# 2013-01-24  0.472641 -0.271681  0.842650 -0.969039
# 2013-01-25  0.199582  2.353817 -0.685744  0.288556
# 2013-01-27  0.728448 -0.168666 -0.407846 -0.535691
# 2013-01-28  0.498953 -0.066302 -0.600534  0.611365
# 2013-01-29  0.902028 -0.185382 -0.528436 -1.092571

# %%
# Selecting values from a DataFrame where a boolean condition is met:
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN  0.317592  0.729468  0.972134
# 2013-01-02       NaN       NaN       NaN  0.336607
# 2013-01-03  0.006409       NaN       NaN  0.556794
# 2013-01-04       NaN       NaN  1.032373       NaN
# 2013-01-05  1.789417  0.153277  0.147893       NaN
# 2013-01-06  0.557691       NaN       NaN  1.331474
# 2013-01-07       NaN       NaN       NaN  0.094531
# 2013-01-08  1.993748       NaN       NaN       NaN
# 2013-01-09  0.199293  1.665368  0.550820       NaN
# 2013-01-10       NaN       NaN  0.351434  0.211844
# 2013-01-11       NaN  0.010199       NaN       NaN
# 2013-01-12       NaN       NaN       NaN  0.660804
# 2013-01-13  0.134320       NaN  0.176931  0.252838
# 2013-01-14  0.477458  0.269147  2.583363       NaN
# 2013-01-15  0.956574  0.176675  1.259434       NaN
# 2013-01-16       NaN       NaN  0.041421  0.340111
# 2013-01-17  0.126396       NaN       NaN       NaN
# 2013-01-18       NaN  0.109429       NaN  0.234449
# 2013-01-19       NaN  0.455917       NaN  0.149275
# 2013-01-20  0.564542       NaN       NaN       NaN
# 2013-01-21       NaN       NaN  0.762714       NaN
# 2013-01-22  0.180451  0.725769       NaN  0.428397
# 2013-01-23  2.090482  0.352674  1.384797  0.104162
# 2013-01-24  0.472641       NaN  0.842650       NaN
# 2013-01-25  0.199582  2.353817       NaN  0.288556
# 2013-01-26       NaN       NaN       NaN       NaN
# 2013-01-27  0.728448       NaN       NaN       NaN
# 2013-01-28  0.498953       NaN       NaN  0.611365
# 2013-01-29  0.902028       NaN       NaN       NaN
# 2013-01-30       NaN       NaN  0.099588  0.409997

# %%
# Using isin() method for filtering:
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 # Using isin() method for filtering:
#       2 df2 = df.copy()
# ----> 3 df2["E"] = ["one", "one", "two", "three", "four", "three"]
#       4 df2
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:4316, in DataFrame.__setitem__(self, key, value)
#    4313     self._setitem_array([key], value)
#    4314 else:
#    4315     # set column
# -> 4316     self._set_item(key, value)
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:4529, in DataFrame._set_item(self, key, value)
#    4519 def _set_item(self, key, value) -> None:
#    4520     """
#    4521     Add series to DataFrame in specified column.
#    4522
#    (...)   4527     ensure homogeneity.
#    4528     """
# -> 4529     value, refs = self._sanitize_column(value)
#    4531     if (
#    4532         key in self.columns
#    4533         and value.ndim == 1
#    4534         and not isinstance(value.dtype, ExtensionDtype)
#    4535     ):
#    4536         # broadcast across multiple columns if necessary
#    4537         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:5273, in DataFrame._sanitize_column(self, value)
#    5270     return _reindex_for_setitem(value, self.index)
#    5272 if is_list_like(value):
# -> 5273     com.require_length_match(value, self.index)
#    5274 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5275 if (
#    5276     isinstance(value, Index)
#    5277     and value.dtype == "object"
#    (...)   5280     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5281     # this deprecation
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (6) does not match length of index (30)

# %%
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.333311 -0.520545 -0.984974  0.375288    one
# 2013-01-02  1.022782  1.821928 -0.226871  0.556099    one
# 2013-01-03 -0.071841 -0.973312 -0.382179  0.515358    two
# 2013-01-04 -0.139286  1.238649  0.035797  1.402802  three
# 2013-01-05  0.215127  1.057997 -1.312619 -0.621037   four
# 2013-01-06  1.694370  2.556249 -0.356801 -0.976552  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.071841 -0.973312 -0.382179  0.515358   two
# 2013-01-05  0.215127  1.057997 -1.312619 -0.621037  four

# %%
# Setting a new column automatically aligns the data by the indexes:
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1

# %%
# Setting values by label:
df.at[dates[0], "A"] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -0.520545 -0.984974  0.375288  NaN
# 2013-01-02  1.022782  1.821928 -0.226871  0.556099  1.0
# 2013-01-03 -0.071841 -0.973312 -0.382179  0.515358  2.0
# 2013-01-04 -0.139286  1.238649  0.035797  1.402802  3.0
# 2013-01-05  0.215127  1.057997 -1.312619 -0.621037  4.0
# 2013-01-06  1.694370  2.556249 -0.356801 -0.976552  5.0

# %%
# Setting values by position:
df.iat[0, 1] = 0

# %%
df
# Out:
#                    A         B         C         D    F
# 2013-01-01  0.000000 -0.520545 -0.984974  0.375288  NaN
# 2013-01-02  1.022782  1.821928 -0.226871  0.556099  1.0
# 2013-01-03 -0.071841 -0.973312 -0.382179  0.515358  2.0
# 2013-01-04 -0.139286  1.238649  0.035797  1.402802  3.0
# 2013-01-05  0.215127  1.057997 -1.312619 -0.621037  4.0
# 2013-01-06  1.694370  2.556249 -0.356801 -0.976552  5.0

# %%
df = pd.DataFrame(
         {
            "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
            "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
            "C": np.random.randn(8),
            "D": np.random.randn(8),
        }
   )
df
# Out:
#      A      B         C         D
# 0  foo    one -1.127777 -0.829567
# 1  bar    one  1.327601  1.663847
# 2  foo    two -0.996186  0.279977
# 3  bar  three  1.219255 -0.441698
# 4  foo    two -1.431400 -0.887511
# 5  bar    two -1.180541 -1.142499
# 6  foo    one -1.211816 -0.283658
# 7  foo  three -0.735811 -2.008655

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar  1.366315  0.079649
# foo -5.502989 -3.729415

# %%
# Grouping by multiple columns label forms MultiIndex.
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    1.327601  1.663847
#     three  1.219255 -0.441698
#     two   -1.180541 -1.142499
# foo one   -2.339593 -1.113225
#     three -0.735811 -2.008655
#     two   -2.427585 -0.607534

# %%
# See the Plotting docs.
# We use the standard convention for referencing the matplotlib API:
import matplotlib.pyplot as plt
plt.close("all")
# The plt.close method is used to close a figure window:
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
import seaborn as sns
kashti=sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 132         0       3  female  47.0      1      0   14.5000        S  Third
# 769         0       3    male  32.0      0      0    8.3625        S  Third
# 787         0       3    male   8.0      4      1   29.1250        Q  Third
# 767         0       3  female  30.5      0      0    7.7500        Q  Third
# 820         1       1  female  52.0      1      1   93.5000        S  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 37          0       3    male  21.0      0      0    8.0500        S  Third
# 574         0       3    male  16.0      0      0    8.0500        S  Third
# 700         1       1  female  18.0      1      0  227.5250        C  First
# 640         0       3    male  20.0      0      0    7.8542        S  Third
# 175         0       3    male  18.0      1      1    7.8542        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 132  woman       False  NaN  Southampton    no  False
# 769    man        True  NaN  Southampton    no   True
# 787  child       False  NaN   Queenstown    no  False
# 767  woman       False  NaN   Queenstown    no   True
# 820  woman       False    B  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 37     man        True  NaN  Southampton    no   True
# 574    man        True  NaN  Southampton    no   True
# 700  woman       False    C    Cherbourg   yes  False
# 640    man        True  NaN  Southampton    no   True
# 175    man        True  NaN  Southampton    no  False
#
# [100 rows x 15 columns]

# %%
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2013-01-04  1.313796 -1.525942 -0.772614 -0.710056
# 2013-01-08  0.830171 -0.034091 -0.442638  0.148730
# 2013-01-09  0.850903 -1.453952 -1.411946  1.617129
# 2013-01-12  0.343377  0.130226 -0.662398  0.419046
# 2013-01-14  0.703865  0.339724 -0.256094  0.830355
# 2013-01-15  0.497625  0.337216 -0.426909  2.112079
# 2013-01-16  0.178558  0.032057  0.435215  0.071070
# 2013-01-17  0.791703 -0.129780  0.258929  0.406026
# 2013-01-18  0.974397 -0.697200 -0.225353 -1.751006
# 2013-01-19  1.318546  0.799190 -0.481535  0.069764
# 2013-01-20  0.996433  1.074042  0.404579  0.378294
# 2013-01-21  0.765070 -0.090598 -0.560926 -1.290317
# 2013-01-22  0.588126 -1.252296 -0.315515 -0.142490
# 2013-01-25  0.877137  0.194841 -0.344772 -0.413395
# 2013-01-27  1.259858  0.427748  0.419475  0.955578
# 2013-01-29  2.303124  0.292680 -0.023355  1.458789
# 2013-01-30  1.151690  0.214476  2.162569  0.741818

# %%
kashti[kashti["age"]<5]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 193         1       2    male  3.00      1      1   26.0000        S  Second
# 205         0       3  female  2.00      0      1   10.4625        S   Third
# 261         1       3    male  3.00      4      2   31.3875        S   Third
# 297         0       1  female  2.00      1      2  151.5500        S   First
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 340         1       2    male  2.00      1      1   26.0000        S  Second
# 348         1       3    male  3.00      1      1   15.9000        S   Third
# 374         0       3  female  3.00      3      1   21.0750        S   Third
# 381         1       3  female  1.00      0      2   15.7417        C   Third
# 386         0       3    male  1.00      5      2   46.9000        S   Third
# 407         1       2    male  3.00      1      1   18.7500        S  Second
# 445         1       1    male  4.00      0      2   81.8583        S   First
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 479         1       3  female  2.00      0      1   12.2875        S   Third
# 530         1       2  female  2.00      1      1   26.0000        S  Second
# 618         1       2  female  4.00      2      1   39.0000        S  Second
# 642         0       3  female  2.00      3      2   27.9000        S   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 691         1       3  female  4.00      0      1   13.4167        C   Third
# 750         1       2  female  4.00      1      1   23.0000        S  Second
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 788         1       3    male  1.00      1      2   20.5750        S   Third
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 824         0       3    male  2.00      4      1   39.6875        S   Third
# 827         1       2    male  1.00      0      2   37.0042        C  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 850         0       3    male  4.00      4      2   31.2750        S   Third
# 869         1       3    male  4.00      1      1   11.1333        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 10   child       False    G  Southampton   yes  False
# 16   child       False  NaN   Queenstown    no  False
# 43   child       False  NaN    Cherbourg   yes  False
# 63   child       False  NaN  Southampton    no  False
# 78   child       False  NaN  Southampton   yes  False
# 119  child       False  NaN  Southampton    no  False
# 164  child       False  NaN  Southampton    no  False
# 171  child       False  NaN   Queenstown    no  False
# 172  child       False  NaN  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False
# 184  child       False  NaN  Southampton   yes  False
# 193  child       False    F  Southampton   yes  False
# 205  child       False    G  Southampton    no  False
# 261  child       False  NaN  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# 305  child       False    C  Southampton   yes  False
# 340  child       False    F  Southampton   yes  False
# 348  child       False  NaN  Southampton   yes  False
# 374  child       False  NaN  Southampton    no  False
# 381  child       False  NaN    Cherbourg   yes  False
# 386  child       False  NaN  Southampton    no  False
# 407  child       False  NaN  Southampton   yes  False
# 445  child       False    A  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 479  child       False  NaN  Southampton   yes  False
# 530  child       False  NaN  Southampton   yes  False
# 618  child       False    F  Southampton   yes  False
# 642  child       False  NaN  Southampton    no  False
# 644  child       False  NaN    Cherbourg   yes  False
# 691  child       False  NaN    Cherbourg   yes  False
# 750  child       False  NaN  Southampton   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 788  child       False  NaN  Southampton   yes  False
# 803  child       False  NaN    Cherbourg   yes  False
# 824  child       False  NaN  Southampton    no  False
# 827  child       False  NaN    Cherbourg   yes  False
# 831  child       False  NaN  Southampton   yes  False
# 850  child       False  NaN  Southampton    no  False
# 869  child       False  NaN  Southampton   yes  False

# %%
kashti[kashti["age"]<60]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [688 rows x 15 columns]

# %%
kashti[kashti["age"]>60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 493         0       1    male  71.0      0      0   49.5042        C   First
# 545         0       1    male  64.0      0      0   26.0000        S   First
# 555         0       1    male  62.0      0      0   26.5500        S   First
# 570         1       2    male  62.0      0      0   10.5000        S  Second
# 625         0       1    male  61.0      0      0   32.3208        S   First
# 630         1       1    male  80.0      0      0   30.0000        S   First
# 672         0       2    male  70.0      0      0   10.5000        S  Second
# 745         0       1    male  70.0      1      1   71.0000        S   First
# 829         1       1  female  62.0      0      0   80.0000      NaN   First
# 851         0       3    male  74.0      0      0    7.7750        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 33     man        True  NaN  Southampton    no   True
# 54     man        True    B    Cherbourg    no  False
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 170    man        True    B  Southampton    no   True
# 252    man        True    C  Southampton    no   True
# 275  woman       False    D  Southampton   yes  False
# 280    man        True  NaN   Queenstown    no   True
# 326    man        True  NaN  Southampton    no   True
# 438    man        True    C  Southampton    no  False
# 456    man        True    E  Southampton    no   True
# 483  woman       False  NaN  Southampton   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# 545    man        True  NaN  Southampton    no   True
# 555    man        True  NaN  Southampton    no   True
# 570    man        True  NaN  Southampton   yes   True
# 625    man        True    D  Southampton    no   True
# 630    man        True    A  Southampton   yes   True
# 672    man        True  NaN  Southampton    no   True
# 745    man        True    B  Southampton    no  False
# 829  woman       False    B          NaN   yes   True
# 851    man        True  NaN  Southampton    no   True

# %%
kashti[kashti["fare"]<5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# 732         0       2  male   NaN      0      0  0.0000        S  Second  man
# 806         0       1  male  39.0      0      0  0.0000        S   First  man
# 815         0       1  male   NaN      0      0  0.0000        S   First  man
# 822         0       1  male  38.0      0      0  0.0000        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 378        True  NaN    Cherbourg    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt
corr=kashti.corr
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("heat map of kashti Data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       2 corr=kashti.corr
#       3 plt.figure(figsize=(10,10))
# ----> 4 sns.heatmap(corr)
#       5 plt.title("heat map of kashti Data")
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)    443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\seaborn\matrix.py:110, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     108 else:
#     109     plot_data = np.asarray(data)
# --> 110     data = pd.DataFrame(plot_data)
#     112 # Validate the mask and convert to DataFrame
#     113 mask = _matrix_mask(data, mask)
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\frame.py:827, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     816         mgr = dict_to_mgr(
#     817             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     818             # attribute "name"
#    (...)    824             copy=_copy,
#     825         )
#     826     else:
# --> 827         mgr = ndarray_to_mgr(
#     828             data,
#     829             index,
#     830             columns,
#     831             dtype=dtype,
#     832             copy=copy,
#     833             typ=manager,
#     834         )
#     836 # For data is list-like, or Iterable (will consume into list)
#     837 elif is_list_like(data):
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\internals\construction.py:314, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     312     else:
#     313         values = np.asarray(values)
# --> 314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
#     319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#
# File c:\Users\Hair\AppData\Local\miniconda3\Lib\site-packages\pandas\core\internals\construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=()
